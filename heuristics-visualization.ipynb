# %% [markdown]
# # Visualization

# %%
import ffp

# %% [markdown]
# ## Name of file

# %%
ffp.startDataFromCSV('mapslocal/10_local_80g_30p_8-10_18False.txt')

# %%
from numpy import genfromtxt
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

adjacency_matrix = ffp.adjacency

rows, cols = np.where(adjacency_matrix == 1)
edges = zip(rows.tolist(), cols.tolist())
gr = nx.Graph()

gr.add_edges_from(edges)
# asign color atribute to nodes
# for numero in range(size_of_graph):
#     gr.nodes[numero]['color'] = color_info[numero]

# dictionary of colors in graph
# color_map = nx.get_node_attributes(gr, 'color')
# graph_colors = [color_map.get(node,'#00b4d9' ) for node in gr.nodes()]

# fix position
my_pos = nx.spring_layout(gr, seed=959595)

nx.draw(gr, node_size=400,  pos = my_pos,  labels=None, with_labels=True)
# nx.draw_networkx_nodes(gr, node_size=500, pos=my_pos, node_color=graph_colors)
plt.show()

# %% [markdown]
# ## Degree Local

# %%
ffp.resetValues()
ffp.ffp(ffp.degreeLocal, True)
print(ffp.n_burned)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6464/4285688087.py in <module>
#       1 ffp.resetValues()
# ----> 2 ffp.ffp(ffp.degreeLocal, True)
#       3 print(ffp.n_burned)
#
# c:\Users\alexc\Documents\Problemas de obtimizacion combinatoria\Firefighter-Problem\ffp.py in ffp(heuristic, info)
#     299             break
#     300
# --> 301         if info : printStatus()
#     302         time_number += 1
#     303
#
# c:\Users\alexc\Documents\Problemas de obtimizacion combinatoria\Firefighter-Problem\ffp.py in printStatus()
#     243
#     244 def printStatus():
# --> 245     showGraphWithLabels(adjacency)
#     246     print('Lista currNode por quemar', next_fire_set)
#     247     print('currNode ya quemados', burned_nodes)
#
# c:\Users\alexc\Documents\Problemas de obtimizacion combinatoria\Firefighter-Problem\ffp.py in showGraphWithLabels(adjacency_matrix)
#      57     # asign color atribute to nodes
#      58     for numero in range(size_of_graph):
# ---> 59         gr.nodes[numero]['color'] = color_info[numero]
#      60
#      61     # dictionary of colors in graph
#
# c:\Users\alexc\AppData\Local\Programs\Python\Python39\lib\site-packages\networkx\classes\reportviews.py in __getitem__(self, n)
#     191                 f"try list(G.nodes)[{n.start}:{n.stop}:{n.step}]"
#     192             )
# --> 193         return self._nodes[n]
#     194
#     195     # Set methods
#
# KeyError: 2

# %% [markdown]
# ## Degree Global

# %%
ffp.resetValues()
ffp.ffp(ffp.degreeGlobal, True)
# Out:
# Lista currNode por quemar set()
# currNode ya quemados [0]
# currNode protegidos [1]
#
# ----------------------------------------

# %% [markdown]
# ## Biggest Sub-tree

# %%
ffp.resetValues()
ffp.ffp(ffp.biggestSubtree, True)
# Out:
# Lista currNode por quemar set()
# currNode ya quemados [0]
# currNode protegidos [1]
#
# ----------------------------------------

# %% [markdown]
# ## Biggest Grand Children

# %%
ffp.resetValues()
ffp.ffp(ffp.biggestGrandChildren, True)
# Out:
# Lista currNode por quemar set()
# currNode ya quemados [0]
# currNode protegidos [1]
#
# ----------------------------------------
